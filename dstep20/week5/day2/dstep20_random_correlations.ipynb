# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("bmh")

# %%
# -- seed the random number generator

# %%
# -- create two random data sets of length 100

# %%
# -- plot them

# %%
# -- calculate the correlation matrix

# %%
# -- pull off the correlation coefficient

# %% [markdown]
# **Now let's do this many, many, many times...**

# %%
# -- initialize a correlation coefficient array

# %%
# -- loop through samples

# %%
# -- make a histogram of the correlation coefficients

# %%
# -- what is the "width" of this Gaussian?
