# %% [markdown]
# # **DSTEP20 // MIDTERM**
#
# **Jan 24, 2020**
#
# ---
#
# In this Midterm you will be working with two data sets in New York City: the Primary Land Use Taxlot Output (PLUTO) and Local Law 84 (LL84) data sets.  PLUTO consists of many building characteristics for each taxlot in the five boroughs while LL84 are the (required by law) annual reportings on energy consumption for buildings over 50,000 sq-ft.
#
# You will explore characteristics of these data sets independently and then in combination to answer several key questions about built structures and their energy use in NYC.
#
# #### **<i><u>All figures must have appropriate axis labels and very brief captions.</u></i>**

# %% [markdown]
# ---

# %% [markdown]
# ## **Working with the PLUTO data**
#
# The PLUTO data for Manhattan is called **MN2017V11.csv** and is available in **dstep20/midterm/data/**.  Each row represents one building in Manhattan in 2017.

# %%
# -- load the PLUTO data (setting low_memory=False) into a DataFrame called plmn

# %% [markdown]
# The "YearBuilt" column contains the year that the building was built.

# %%
# -- when was the oldest building built according to the PLUTO data?

# %%
# -- when was the youngest building built according to the PLUTO data?

# %%
# -- create a new DataFrame called plmn_sp by sub-selecting only those buildings built after 1900 and before 2018

# %% [markdown]
# The square footage of the building is contained in the BldgArea column.

# %%
# -- what is the average square footage of buildings built between 1900 and 2018 in the PLUTO data?

# %%
# -- what is the median of square footage of buildings built between 1900 and 2018 in the PLUTO data?

# %%
# -- is the square footage of buildings in Manhattan built between 1900 and 2018 Normally distributed?  how do you know?

# %%
# -- how many NaNs are in the first 10 columns in plmn_sp?

# %%
# -- group plmn_sp by year built and sum to get the totals for each column in a given year

# %%
# -- use the above calculation to make a line plot of built area in a given year as a function of time

# %% [markdown]
# ---

# %% [markdown]
# ## **Working with Local Law 84 Data**
#
# The LL84 data is called **local_law_84.csv** and is available in **dstep20/midterm/data/**.  Each row represents one building's energy consumption characteristics in 2017.

# %%
# -- load the LL84 data (setting low_memory=False) into a DataFrame called ll84

# %%
# -- sub-select only those rows in ll84 that represent buildings in Manhattan

# %%
# -- create a DataFrame called ll84_eui that contains only the "BBL" and "EUI (kBtu/sqft)" columns of ll84

# %%
# -- sort ll84_eui to find the top 10 buildings that had the highest energy use intensity "EUI (kBtu/sqft)" in 2017 and note the BBL of the largest consumer

# %%
# -- using the "OwnerName" and "BBL" columns in PLUTO, print the name of the owner of the building that had the highest energy use intensity in 2017

# %% [markdown]
# ---

# %% [markdown]
# ## **Estimating the Relationship Between Building Size and Energy Consumption**
#
# A preprocessed file that merges LL84 and PLUTO data is called **pluto_mn_ll84.csv** and is available in **dstep20/midterm/data/**.  Each row represents one building in Manhattan 2017.

# %%
# -- load the merged PLUTO and LL84 file from Google Drive

# %%
# -- sub-select only those rows for which total energy consumption is greater than zero

# %%
# -- create a column called logBA that is the log10 of the Building Area in square feet

# %%
# -- create a column called logE that is the log10 of the energy consumption in kBtu

# %%
# -- make a scatter plot of log(energy consumption) vs log(building area) setting the transparency keyword alpha to 0.1

# %%
# -- fit a linear model to log(energy consumption) vs log(building area)

# %%
# -- fit a quadratic model to log(energy consumption) vs log(building area)

# %%
# -- overplot the linear and quadratic model on the data

# %%
# -- use a likelihood ratio test to compare the two models (i.e., what is the p-value and its interpretation?)

# %%
# -- a developer is planning to build a 10,000,000 sqft building.  How much energy in kBtu do the models predict it will consume?
