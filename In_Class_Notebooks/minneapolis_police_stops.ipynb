# %% [markdown]
# ## **DSTEP20 // Open Minneapolis: Police Stops**
# <small> January 15, 2020 </small>
#
# **In 2017, did police stops in Minneapolis that involve a person of color also involve a personal search more frequently than do stops involving white people?**
#
# The data can be found [here](http://opendata.minneapolismn.gov/datasets/police-stop-data).
#
# ---

# %% [markdown]
# ### **Loading the data**

# %% [markdown]
# As always, our first step is to load the data, and take a quick look at its contents.

# %%
# -- imports
import numpy as np
import pandas as pd
import qgrid
# from google.colab.widgets import qgrid

pd.set_option('display.max_columns', 500)

# %%
# !curl -sL https://opendata.arcgis.com/datasets/215b4b543d894750aef86c725b56ee2a_0.csv | head
# Out:
# ﻿OBJECTID,masterIncidentNumber,responseDate,reason,problem,callDisposition,citationIssued,personSearch,vehicleSearch,preRace,race,gender,lat,long,x,y,policePrecinct,neighborhood,lastUpdateDate
# 4001,16-436972,2016-12-05T10:17:07.000Z,,Traffic Law Enforcement (P),TAG-Tagged,,NO,NO,White,White,Female,44.9895,-93.25564,-10381170.34,5619868.78,2,Nicollet Island - East Bank,2017-08-08T10:25:31.000Z
# 4002,16-436976,2016-12-05T10:19:15.000Z,,Traffic Law Enforcement (P),TAG-Tagged,,NO,NO,Unknown,Black,Male,45.01316127,-93.2709171,-10382870.9972,5623593.6963,2,Bottineau,2017-08-08T10:26:13.000Z
# 4003,16-436992,2016-12-05T10:30:53.000Z,,Suspicious Person (P),RPT-Report,,NO,NO,Unknown,Unknown,Male,44.95821728,-93.26511837,-10382225.486,5614946.0495,3,Phillips West,2017-08-08T10:24:35.000Z
# 4004,16-437002,2016-12-05T10:47:42.000Z,,Traffic Law Enforcement (P),ADV-Advised,,NO,NO,White,White,Female,45.01196,-93.28058,-10383947.08,5623404.519,4,Hawthorne,2017-08-08T10:25:31.000Z
# 4005,16-437012,2016-12-05T10:58:38.000Z,,Suspicious Vehicle (P),AOK- All OK,,NO,NO,Unknown,Unknown,Gender Non-Conforming,44.98773916,-93.25710591,-10381333.5433,5619591.4736,2,Nicollet Island - East Bank,2017-08-08T10:26:13.000Z
# 4006,16-437034,2016-12-05T11:23:57.000Z,,Traffic Law Enforcement (P),TAG-Tagged,,NO,NO,Unknown,Black,Male,44.99883,-93.3159,-10387878.67,5621336.955,4,Willard - Hay,2017-08-08T10:25:31.000Z
# 4007,16-437050,2016-12-05T11:36:11.000Z,,Traffic Law Enforcement (P),ADV-Advised,,NO,NO,Unknown,Black,Male,44.99875,-93.30443,-10386601.94,5621324.752,4,Willard - Hay,2017-08-08T10:25:31.000Z
# 4008,16-437051,2016-12-05T11:36:49.000Z,,Suspicious Vehicle (P),TOW-Towed,,NO,NO,Unknown,Unknown,Unknown,45.02307959,-93.29562779,-10385621.7791,5625155.6277,4,Folwell,2017-08-08T10:24:35.000Z
# 4009,16-437056,2016-12-05T11:42:46.000Z,,Traffic Law Enforcement (P),TAG-Tagged,,NO,NO,Unknown,Asian,Male,44.99633,-93.30695,-10386882.64,5620944.41,4,Willard - Hay,2017-08-08T10:25:31.000Z

# %%
# -- set the file name
fname = 'https://opendata.arcgis.com/datasets/215b4b543d894750aef86c725b56ee2a_0.csv'

# -- load the data
stops = pd.read_csv(fname, header=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Interesting warning... let's try to follow its recommendations:

# %%
# -- re-load the data
stops = pd.read_csv(fname, header=0, low_memory=False)

# %%
# -- print the dataframe
display(stops)
# Out:
#         OBJECTID masterIncidentNumber              responseDate  \
# 0           4001            16-436972  2016-12-05T10:17:07.000Z
# 1           4002            16-436976  2016-12-05T10:19:15.000Z
# 2           4003            16-436992  2016-12-05T10:30:53.000Z
# 3           4004            16-437002  2016-12-05T10:47:42.000Z
# 4           4005            16-437012  2016-12-05T10:58:38.000Z
# ...          ...                  ...                       ...
# 146724    146725            20-012269  2020-01-15T03:43:55.000Z
# 146725    146726            20-012273  2020-01-15T04:15:20.000Z
# 146726    146727            20-012276  2020-01-15T04:18:36.000Z
# 146727    146728            20-012280  2020-01-15T04:37:20.000Z
# 146728    146729            20-012281  2020-01-15T04:42:44.000Z
#
#                      reason                      problem      callDisposition  \
# 0                       NaN  Traffic Law Enforcement (P)           TAG-Tagged
# 1                       NaN  Traffic Law Enforcement (P)           TAG-Tagged
# 2                       NaN        Suspicious Person (P)           RPT-Report
# 3                       NaN  Traffic Law Enforcement (P)          ADV-Advised
# 4                       NaN       Suspicious Vehicle (P)          AOK- All OK
# ...                     ...                          ...                  ...
# 146724      Citizen / 9-1-1        Suspicious Person (P)        AQT-All Quiet
# 146725  Equipment Violation  Traffic Law Enforcement (P)          ADV-Advised
# 146726        Investigative       Suspicious Vehicle (P)          AOK- All OK
# 146727      Citizen / 9-1-1       Suspicious Vehicle (P)          AOK- All OK
# 146728      Citizen / 9-1-1        Suspicious Person (P)  GOA-Gone on Arrival
#
#        citationIssued personSearch vehicleSearch  preRace     race  \
# 0                 NaN           NO            NO    White    White
# 1                 NaN           NO            NO  Unknown    Black
# 2                 NaN           NO            NO  Unknown  Unknown
# 3                 NaN           NO            NO    White    White
# 4                 NaN           NO            NO  Unknown  Unknown
# ...               ...          ...           ...      ...      ...
# 146724             NO           NO            NO  Unknown  Unknown
# 146725             NO           NO            NO  Unknown    Black
# 146726             NO           NO            NO  Unknown  Unknown
# 146727             NO           NO            NO  Unknown  Unknown
# 146728             NO           NO            NO    Black    Black
#
#                        gender        lat       long             x  \
# 0                      Female  44.989500 -93.255640 -1.038117e+07
# 1                        Male  45.013161 -93.270917 -1.038287e+07
# 2                        Male  44.958217 -93.265118 -1.038223e+07
# 3                      Female  45.011960 -93.280580 -1.038395e+07
# 4       Gender Non-Conforming  44.987739 -93.257106 -1.038133e+07
# ...                       ...        ...        ...           ...
# 146724                   Male  45.013225 -93.305207 -1.038669e+07
# 146725                   Male  45.005992 -93.302520 -1.038639e+07
# 146726                Unknown  44.993320 -93.308220 -1.038702e+07
# 146727                Unknown  45.004560 -93.299970 -1.038611e+07
# 146728                   Male  44.973712 -93.264750 -1.038218e+07
#
#                    y  policePrecinct                 neighborhood  \
# 0       5.619869e+06             2.0  Nicollet Island - East Bank
# 1       5.623594e+06             2.0                    Bottineau
# 2       5.614946e+06             3.0                Phillips West
# 3       5.623405e+06             4.0                    Hawthorne
# 4       5.619591e+06             2.0  Nicollet Island - East Bank
# ...              ...             ...                          ...
# 146724  5.623604e+06             4.0                      Folwell
# 146725  5.622465e+06             4.0                       Jordan
# 146726  5.620470e+06             4.0                Willard - Hay
# 146727  5.622240e+06             4.0                       Jordan
# 146728  5.617384e+06             1.0                  Elliot Park
#
#                   lastUpdateDate
# 0       2017-08-08T10:25:31.000Z
# 1       2017-08-08T10:26:13.000Z
# 2       2017-08-08T10:24:35.000Z
# 3       2017-08-08T10:25:31.000Z
# 4       2017-08-08T10:26:13.000Z
# ...                          ...
# 146724  2020-01-15T08:20:19.000Z
# 146725  2020-01-15T08:20:21.000Z
# 146726  2020-01-15T08:20:20.000Z
# 146727  2020-01-15T08:20:20.000Z
# 146728  2020-01-15T08:20:18.000Z
#
# [146729 rows x 19 columns]

# %%
qq = qgrid.show_grid(stops, show_toolbar=True)
display(qq)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# ---

# %% [markdown]
# ### **Data Manipulations Part 1: from slicing to indexing**

# %% [markdown]
# What if we wanted stops for the year 2017?  How would we "sub-select" only those rows?

# %% [markdown]
# Well, first let's figure out what data type is in the responseDate column,

# %%
# -- check data dtype of first element of response date column
print(type(stops["responseDate"].iloc[0]))
# Out:
# <class 'str'>

# %% [markdown]
# Looks like it's a string.  So let's start with a string method like we saw last time.  This time let's use the "contains" string method,

# %%
# -- print the result of using the "contains" method to see what rows of 
#    response date include contain the string "2017"
print(stops["responseDate"].str.contains('2017'))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 146724    False
# 146725    False
# 146726    False
# 146727    False
# 146728    False
# Name: responseDate, Length: 146729, dtype: bool

# %% [markdown]
# The first five and last five rows are all False (note the dtype...), but are there any True in there?  To find out, first note the following:

# %%
# -- example boolean NumPy array
barr = np.array([True, True, False, True, False, False, True])

# -- summing it treats the True's as 1's and the False's as 0's
print(barr.sum())
# Out:
# 4

# %% [markdown]
# So, how would we find out if the output of contains("2017") is True somewhere inside those ...'s ?

# %%
# -- check if any response dates contain the string "2017"
n2017 = stops["responseDate"].str.contains('2017').sum()

print("total number of response dates in 2017: {0}".format(n2017))
# Out:
# total number of response dates in 2017: 54156

# %% [markdown]
# Already now, we can answer a potentially interesting policy question, **how many stops per year from 2017 to 2019**?

# %%
# -- create a new DataFrame containing the number of stops in 2017, 
#    2018, and 2019, and make a bar plot

# -- calculate number of stops for each year
n2017 = stops["responseDate"].str.contains('2017').sum()
n2018 = stops["responseDate"].str.contains('2018').sum()
n2019 = stops["responseDate"].str.contains('2019').sum()

# -- make a list of lists and create a DataFrame
ll_stops = [[2017, n2017], [2018, n2018], [2019, n2019]]
stops_df = pd.DataFrame(ll_stops, columns=["year", "nstops"])

# -- make a bar plot
ax   = stops_df.plot.bar(x = 'year', y = 'nstops')
xlab = ax.set_xlabel('year')
ylab = ax.set_ylabel('Number of Stops')

# %% [markdown]
# How would you interpret this plot?

# %% [markdown]
# Now, let's finish sub-selecting only 2017 stops for further analysis.  Notice the following:

# %%
# -- create a number array with some values that is the SAME LENGTH as the 
#    boolean array (barr) created above
myarr = np.array([62.3, -23, 63, 94, 1, -22.5, 0.88])

# -- print ONLY values where barr is True
print(myarr)
print(barr)
print(myarr[barr])
# Out:
# [ 62.3  -23.    63.    94.     1.   -22.5    0.88]
# [ True  True False  True False False  True]
# [ 62.3  -23.    94.     0.88]

# %% [markdown]
# This is type of operation is called "indexing" and is an extension of the "slicing" concept we've seen before:

# %%
# -- slicing:
print(myarr[2:5])

# -- indexing
ind = np.array([False, False, True, True, True, False, False])
print(myarr[ind])
# Out:
# [63. 94.  1.]
# [63. 94.  1.]

# %% [markdown]
# But notice that the output of our .str.contains("2017") method call was exactly a True/False (boolean) array!  So now we can finally subset our Minneapolis stops data to only 2017:

# %%
# -- create a True/False index of when response date contains 2017
ind = np.array(stops["responseDate"].str.contains('2017'))

# -- sub-select only those rows
stops17 = stops[ind]

# -- print the result
display(stops17)
# Out:
#        OBJECTID masterIncidentNumber              responseDate  \
# 1000      10001            17-029747  2017-01-25T22:24:52.000Z
# 1001      10002            17-029769  2017-01-25T22:45:20.000Z
# 1002      10003            17-029776  2017-01-25T22:50:14.000Z
# 1003      10004            17-029779  2017-01-25T22:54:24.000Z
# 1004      10005            17-029787  2017-01-25T22:59:30.000Z
# ...         ...                  ...                       ...
# 94595     95596            17-473484  2017-12-15T06:49:27.000Z
# 94596     95597            17-479333  2017-12-20T11:37:20.000Z
# 94597     95598            17-487421  2017-12-28T07:57:56.000Z
# 94598     95599            17-488696  2017-12-29T07:52:07.000Z
# 94599     95600            17-488702  2017-12-29T07:58:43.000Z
#
#                  reason                      problem       callDisposition  \
# 1000                NaN        Suspicious Person (P)  UTL-Unable to Locate
# 1001                NaN  Traffic Law Enforcement (P)           ADV-Advised
# 1002                NaN       Suspicious Vehicle (P)       INF-Information
# 1003                NaN        Suspicious Person (P)           ADV-Advised
# 1004                NaN  Traffic Law Enforcement (P)           ADV-Advised
# ...                 ...                          ...                   ...
# 94595   Citizen / 9-1-1        Suspicious Person (P)   GOA-Gone on Arrival
# 94596               NaN          Attempt Pick-Up (P)                   NaN
# 94597  Moving Violation  Traffic Law Enforcement (P)            TAG-Tagged
# 94598               NaN        Suspicious Person (P)              SNT-Sent
# 94599   Citizen / 9-1-1       Suspicious Vehicle (P)   GOA-Gone on Arrival
#
#       citationIssued personSearch vehicleSearch  preRace             race  \
# 1000             NaN           NO            NO  Unknown          Unknown
# 1001             NaN           NO            NO  Unknown            Black
# 1002             NaN           NO            NO  Unknown          Unknown
# 1003             NaN           NO            NO  Unknown  Native American
# 1004             NaN           NO            NO  Unknown  Native American
# ...              ...          ...           ...      ...              ...
# 94595             NO           NO            NO  Unknown          Unknown
# 94596            NaN          NaN           NaN      NaN              NaN
# 94597            YES           NO            NO  Unknown            Black
# 94598            NaN          NaN           NaN      NaN              NaN
# 94599             NO           NO            NO  Unknown          Unknown
#
#         gender        lat       long             x             y  \
# 1000   Unknown  45.011627 -93.264648 -1.038217e+07  5.623352e+06
# 1001      Male  44.962266 -93.258192 -1.038145e+07  5.615583e+06
# 1002   Unknown  44.955998 -93.247356 -1.038025e+07  5.614597e+06
# 1003      Male  44.961376 -93.252331 -1.038080e+07  5.615443e+06
# 1004    Female  44.959137 -93.247940 -1.038031e+07  5.615091e+06
# ...        ...        ...        ...           ...           ...
# 94595  Unknown  44.925070 -93.227040 -1.037799e+07  5.609733e+06
# 94596      NaN  44.960052 -93.268978 -1.038266e+07  5.615235e+06
# 94597   Female  44.993070 -93.304460 -1.038660e+07  5.620430e+06
# 94598      NaN  44.978459 -93.277331 -1.038359e+07  5.618131e+06
# 94599  Unknown  45.005551 -93.303153 -1.038646e+07  5.622395e+06
#
#        policePrecinct     neighborhood            lastUpdateDate
# 1000              2.0        Bottineau  2017-08-08T10:24:35.000Z
# 1001              3.0  Ventura Village  2017-08-08T10:26:13.000Z
# 1002              3.0    East Phillips  2017-08-08T10:26:13.000Z
# 1003              3.0  Ventura Village  2017-08-08T10:26:13.000Z
# 1004              3.0    East Phillips  2017-08-08T10:26:13.000Z
# ...               ...              ...                       ...
# 94595             3.0         Ericsson  2018-10-02T13:45:38.000Z
# 94596             3.0    Phillips West  2018-10-02T13:45:30.000Z
# 94597             4.0    Willard - Hay  2018-10-02T13:45:38.000Z
# 94598             1.0    Downtown West  2018-10-02T13:45:16.000Z
# 94599             4.0           Jordan  2018-10-02T13:45:49.000Z
#
# [54156 rows x 19 columns]

# %% [markdown]
# There is one last bit of indexing that we'll need to subset this data into a form that we want: "relational indexing".
#
# Again, notice the following,

# %%
# -- create a number array with some values
myarr = np.array([62.3, -23, 63, 94, 1, -22.5, 0.88])

# -- print ONLY values that are negative
ind = myarr < 0.0
print(ind)
print(myarr[ind])
# Out:
# [False  True False False False  True False]
# [-23.  -22.5]

# %%
# -- here are some examples of these types of logical relations
print("1. {0}".format(myarr >= 1))
print("2. {0}".format(myarr == 0.88))
print("3. {0}".format(myarr != 63))
# Out:
# 1. [ True False  True  True  True False False]
# 2. [False False False False False False  True]
# 3. [ True  True False  True  True  True  True]

# %% [markdown]
# With this, we have the tools to answer the question: **<i>"in 2017, what fraction of stops involved a person of color?"</i>**, right?

# %%
# -- create True/False arrays for White and not White
ind_wht = stops17["race"] == 'White'
ind_poc = stops17["race"] != 'White'

nstops17 = len(stops17)
nwht17 = len(stops17[ind_wht])
npoc17 = len(stops17[ind_poc])

print("fraction of subjects that are white     : {0:4.3}".format(nwht17 / nstops17))
print("fraction of subjects that are not white : {0:4.3}".format(npoc17 / nstops17))
# Out:
# fraction of subjects that are white     : 0.222
# fraction of subjects that are not white : 0.778

# %% [markdown]
# **Not so fast...**, we still have to deal with NaN's, type of stop, etc.

# %% [markdown]
# ---

# %% [markdown]
# ### **Data Manipulations Part 2: removing NaNs and groupings**

# %% [markdown]
# What to do about NaNs is a complex consideration without a universal answer.  Different situations and different contexts require different handling of NaN values.
#
# #### **<i>Regardless of what you do with NaNs, the <u>most</u> important thing is to acknowledge your choice and describe its consequences when presenting results.</i>**

# %% [markdown]
# For now, let's drop NaNs using the 2017 DataFrame's .dropna method,

# %%
# -- drop NaNs
display(stops17.dropna())
# Out:
#        OBJECTID masterIncidentNumber              responseDate  \
# 35000     38001            17-264706  2017-07-15T00:44:06.000Z
# 35001     38002            17-264708  2017-07-15T00:45:15.000Z
# 35002     38003            17-264713  2017-07-15T00:48:26.000Z
# 35003     38004            17-264718  2017-07-15T00:51:51.000Z
# 35004     38005            17-264734  2017-07-15T01:05:55.000Z
# ...         ...                  ...                       ...
# 94593     95594            17-469769  2017-12-12T06:31:50.000Z
# 94594     95595            17-472268  2017-12-14T07:42:24.000Z
# 94595     95596            17-473484  2017-12-15T06:49:27.000Z
# 94597     95598            17-487421  2017-12-28T07:57:56.000Z
# 94599     95600            17-488702  2017-12-29T07:58:43.000Z
#
#                     reason                      problem      callDisposition  \
# 35000      Citizen / 9-1-1       Suspicious Vehicle (P)      INF-Information
# 35001        Investigative       Suspicious Vehicle (P)          AOK- All OK
# 35002     Moving Violation  Traffic Law Enforcement (P)           TAG-Tagged
# 35003  Equipment Violation  Traffic Law Enforcement (P)          ADV-Advised
# 35004  Equipment Violation  Traffic Law Enforcement (P)          ADV-Advised
# ...                    ...                          ...                  ...
# 94593      Citizen / 9-1-1        Suspicious Person (P)    FTC-Fail to Clear
# 94594      Citizen / 9-1-1        Suspicious Person (P)        UNF-Unfounded
# 94595      Citizen / 9-1-1        Suspicious Person (P)  GOA-Gone on Arrival
# 94597     Moving Violation  Traffic Law Enforcement (P)           TAG-Tagged
# 94599      Citizen / 9-1-1       Suspicious Vehicle (P)  GOA-Gone on Arrival
#
#       citationIssued personSearch vehicleSearch  preRace     race   gender  \
# 35000             NO           NO            NO  Unknown    White     Male
# 35001             NO           NO            NO  Unknown  Unknown  Unknown
# 35002            YES           NO            NO  Unknown    Asian   Female
# 35003             NO           NO            NO  Unknown    Black   Female
# 35004             NO          YES           YES  Unknown    Black     Male
# ...              ...          ...           ...      ...      ...      ...
# 94593             NO           NO            NO  Unknown  Unknown  Unknown
# 94594             NO           NO            NO  Unknown  Unknown  Unknown
# 94595             NO           NO            NO  Unknown  Unknown  Unknown
# 94597            YES           NO            NO  Unknown    Black   Female
# 94599             NO           NO            NO  Unknown  Unknown  Unknown
#
#              lat       long             x             y  policePrecinct  \
# 35000  44.910804 -93.225005 -1.037776e+07  5.607490e+06             3.0
# 35001  44.960903 -93.275912 -1.038343e+07  5.615369e+06             5.0
# 35002  44.979187 -93.273109 -1.038312e+07  5.618245e+06             1.0
# 35003  45.013160 -93.247340 -1.038025e+07  5.623594e+06             2.0
# 35004  45.013170 -93.255510 -1.038116e+07  5.623594e+06             2.0
# ...          ...        ...           ...           ...             ...
# 94593  45.012317 -93.304442 -1.038660e+07  5.623461e+06             4.0
# 94594  44.924225 -93.256208 -1.038123e+07  5.609600e+06             3.0
# 94595  44.925070 -93.227040 -1.037799e+07  5.609733e+06             3.0
# 94597  44.993070 -93.304460 -1.038660e+07  5.620430e+06             4.0
# 94599  45.005551 -93.303153 -1.038646e+07  5.622395e+06             4.0
#
#         neighborhood            lastUpdateDate
# 35000      Keewaydin  2017-08-08T10:24:35.000Z
# 35001       Whittier  2017-08-08T10:26:13.000Z
# 35002  Downtown West  2017-08-08T10:26:13.000Z
# 35003   Audubon Park  2017-08-08T10:25:31.000Z
# 35004        Holland  2017-08-08T10:25:31.000Z
# ...              ...                       ...
# 94593         Jordan  2018-10-02T13:45:16.000Z
# 94594       Northrop  2018-10-02T13:45:16.000Z
# 94595       Ericsson  2018-10-02T13:45:38.000Z
# 94597  Willard - Hay  2018-10-02T13:45:38.000Z
# 94599         Jordan  2018-10-02T13:45:49.000Z
#
# [19673 rows x 19 columns]

# %% [markdown]
# How many rows did we lose?

# %%
# -- check how many rows were dropped
print(len(stops17.dropna()) / len(stops17))
# Out:
# 0.3632653814905089

# %% [markdown]
# That's a lot of lost data!  Perhaps we are being a bit restrictive.  For example, for the question we're trying to answer (BUT NOT OTHER QUESTIONS!), the preRace value may be fine taking on a NaN value.  Let's check which columns have the most NaN's using the .isna method and summing across the 0'th axis:

# %%
# -- print out how many NaNs per column
print(stops17.isna().sum(axis=0))
# Out:
# OBJECTID                    0
# masterIncidentNumber        0
# responseDate                0
# reason                  19316
# problem                     0
# callDisposition          1163
# citationIssued          34292
# personSearch             8854
# vehicleSearch            8854
# preRace                  8854
# race                     8854
# gender                   8854
# lat                         0
# long                        0
# x                           0
# y                           0
# policePrecinct            683
# neighborhood              683
# lastUpdateDate              0
# dtype: int64

# %% [markdown]
# Since we're mostly interested in the race and personSearch columns, perhaps we can drop only rows that have NaNs in those columns:

# %%
# -- drop NaNs from race and personSearch columns and send to a new DataFrame
indr = ~stops17["race"].isna() # race column is not NaN
indp = ~stops17["personSearch"].isna() # personSearch column is not NaN

ind_tot = indr & indp # combine indices (meaning both must be True)
sub17 = stops17[ind_tot]

display(sub17)
# Out:
#        OBJECTID masterIncidentNumber              responseDate  \
# 1000      10001            17-029747  2017-01-25T22:24:52.000Z
# 1001      10002            17-029769  2017-01-25T22:45:20.000Z
# 1002      10003            17-029776  2017-01-25T22:50:14.000Z
# 1003      10004            17-029779  2017-01-25T22:54:24.000Z
# 1004      10005            17-029787  2017-01-25T22:59:30.000Z
# ...         ...                  ...                       ...
# 94593     95594            17-469769  2017-12-12T06:31:50.000Z
# 94594     95595            17-472268  2017-12-14T07:42:24.000Z
# 94595     95596            17-473484  2017-12-15T06:49:27.000Z
# 94597     95598            17-487421  2017-12-28T07:57:56.000Z
# 94599     95600            17-488702  2017-12-29T07:58:43.000Z
#
#                  reason                      problem       callDisposition  \
# 1000                NaN        Suspicious Person (P)  UTL-Unable to Locate
# 1001                NaN  Traffic Law Enforcement (P)           ADV-Advised
# 1002                NaN       Suspicious Vehicle (P)       INF-Information
# 1003                NaN        Suspicious Person (P)           ADV-Advised
# 1004                NaN  Traffic Law Enforcement (P)           ADV-Advised
# ...                 ...                          ...                   ...
# 94593   Citizen / 9-1-1        Suspicious Person (P)     FTC-Fail to Clear
# 94594   Citizen / 9-1-1        Suspicious Person (P)         UNF-Unfounded
# 94595   Citizen / 9-1-1        Suspicious Person (P)   GOA-Gone on Arrival
# 94597  Moving Violation  Traffic Law Enforcement (P)            TAG-Tagged
# 94599   Citizen / 9-1-1       Suspicious Vehicle (P)   GOA-Gone on Arrival
#
#       citationIssued personSearch vehicleSearch  preRace             race  \
# 1000             NaN           NO            NO  Unknown          Unknown
# 1001             NaN           NO            NO  Unknown            Black
# 1002             NaN           NO            NO  Unknown          Unknown
# 1003             NaN           NO            NO  Unknown  Native American
# 1004             NaN           NO            NO  Unknown  Native American
# ...              ...          ...           ...      ...              ...
# 94593             NO           NO            NO  Unknown          Unknown
# 94594             NO           NO            NO  Unknown          Unknown
# 94595             NO           NO            NO  Unknown          Unknown
# 94597            YES           NO            NO  Unknown            Black
# 94599             NO           NO            NO  Unknown          Unknown
#
#         gender        lat       long             x             y  \
# 1000   Unknown  45.011627 -93.264648 -1.038217e+07  5.623352e+06
# 1001      Male  44.962266 -93.258192 -1.038145e+07  5.615583e+06
# 1002   Unknown  44.955998 -93.247356 -1.038025e+07  5.614597e+06
# 1003      Male  44.961376 -93.252331 -1.038080e+07  5.615443e+06
# 1004    Female  44.959137 -93.247940 -1.038031e+07  5.615091e+06
# ...        ...        ...        ...           ...           ...
# 94593  Unknown  45.012317 -93.304442 -1.038660e+07  5.623461e+06
# 94594  Unknown  44.924225 -93.256208 -1.038123e+07  5.609600e+06
# 94595  Unknown  44.925070 -93.227040 -1.037799e+07  5.609733e+06
# 94597   Female  44.993070 -93.304460 -1.038660e+07  5.620430e+06
# 94599  Unknown  45.005551 -93.303153 -1.038646e+07  5.622395e+06
#
#        policePrecinct     neighborhood            lastUpdateDate
# 1000              2.0        Bottineau  2017-08-08T10:24:35.000Z
# 1001              3.0  Ventura Village  2017-08-08T10:26:13.000Z
# 1002              3.0    East Phillips  2017-08-08T10:26:13.000Z
# 1003              3.0  Ventura Village  2017-08-08T10:26:13.000Z
# 1004              3.0    East Phillips  2017-08-08T10:26:13.000Z
# ...               ...              ...                       ...
# 94593             4.0           Jordan  2018-10-02T13:45:16.000Z
# 94594             3.0         Northrop  2018-10-02T13:45:16.000Z
# 94595             3.0         Ericsson  2018-10-02T13:45:38.000Z
# 94597             4.0    Willard - Hay  2018-10-02T13:45:38.000Z
# 94599             4.0           Jordan  2018-10-02T13:45:49.000Z
#
# [45302 rows x 19 columns]

# %%
# -- check the results
print(sub17.isna().sum(axis=0))

print("")

# -- check how many rows were dropped
print(len(sub17) / len(stops17))
# Out:
# OBJECTID                    0
# masterIncidentNumber        0
# responseDate                0
# reason                  10462
# problem                     0
# callDisposition             0
# citationIssued          25438
# personSearch                0
# vehicleSearch               0
# preRace                     0
# race                        0
# gender                      0
# lat                         0
# long                        0
# x                           0
# y                           0
# policePrecinct            508
# neighborhood              508
# lastUpdateDate              0
# dtype: int64
#
# 0.8365093433783883

# %% [markdown]
# And so we've only had to discard about 16.5% of our data for this question.

# %% [markdown]
# Now let's find the total number of stops for each race using the powerful .groupby method,

# %%
# -- groupy by race and count stops
sub17.groupby(['race']).count()
# Out:
#                  OBJECTID  masterIncidentNumber  responseDate  reason  \
# race
# Asian                 673                   673           673     497
# Black               15790                 15790         15790   12095
# East African         2225                  2225          2225    1665
# Latino               1909                  1909          1909    1455
# Native American      1604                  1604          1604    1265
# Other                1422                  1422          1422    1046
# Unknown              9645                  9645          9645    7794
# White               12034                 12034         12034    9023
#
#                  problem  callDisposition  citationIssued  personSearch  \
# race
# Asian                673              673             260           673
# Black              15790            15790            6956         15790
# East African        2225             2225             846          2225
# Latino              1909             1909             748          1909
# Native American     1604             1604             737          1604
# Other               1422             1422             599          1422
# Unknown             9645             9645            4860          9645
# White              12034            12034            4858         12034
#
#                  vehicleSearch  preRace  gender    lat   long      x      y  \
# race
# Asian                      673      673     673    673    673    673    673
# Black                    15790    15790   15790  15790  15790  15790  15790
# East African              2225     2225    2225   2225   2225   2225   2225
# Latino                    1909     1909    1909   1909   1909   1909   1909
# Native American           1604     1604    1604   1604   1604   1604   1604
# Other                     1422     1422    1422   1422   1422   1422   1422
# Unknown                   9645     9645    9645   9645   9645   9645   9645
# White                    12034    12034   12034  12034  12034  12034  12034
#
#                  policePrecinct  neighborhood  lastUpdateDate
# race
# Asian                       660           660             673
# Black                     15634         15634           15790
# East African               2205          2205            2225
# Latino                     1891          1891            1909
# Native American            1583          1583            1604
# Other                      1397          1397            1422
# Unknown                    9558          9558            9645
# White                     11866         11866           12034

# %% [markdown]
# There is much to say about groupby objects:
#
# - index is now the values
# - need to have .groupby followed by summary function (count, sum, first, mean, etc.)
# - can pop index back into output with .reset_index method

# %% [markdown]
# We can use this grouped DataFrame to get the total number of stops for each race

# %%
# -- make counts by race DataFrame
cbr17 = sub17.groupby(['race']).count()

# %%
# -- get the index
rind = cbr17.index

print(rind)
# Out:
# Index(['Asian', 'Black', 'East African', 'Latino', 'Native American', 'Other',
#        'Unknown', 'White'],
#       dtype='object', name='race')

# %%
# -- get the total number of stopped white persons (nb, we know that OBJECTID 
#    has no NaN values)
nstop_wht = cbr17["OBJECTID"].loc["White"]

# %%
# -- get the total non-white stops (NOTE: IT'S IMPORTANT THAT WE HAVE EXCLUDED 
#    THE "UNKNOWN" CATEGORY)
print(cbr17["OBJECTID"].loc[rind[:6]])

nstop_poc = cbr17["OBJECTID"].loc[rind[:6]].sum()
# Out:
# race
# Asian                673
# Black              15790
# East African        2225
# Latino              1909
# Native American     1604
# Other               1422
# Name: OBJECTID, dtype: int64

# %%
# -- print out the results
print("total number of stops with white subject : {0}".format(nstop_wht))
print("total number of stops with poc subject   : {0}".format(nstop_poc))
# Out:
# total number of stops with white subject : 12034
# total number of stops with poc subject   : 23623

# %%
cbr17.keys()
# Out:
# Index(['OBJECTID', 'masterIncidentNumber', 'responseDate', 'reason', 'problem',
#        'callDisposition', 'citationIssued', 'personSearch', 'vehicleSearch',
#        'preRace', 'gender', 'lat', 'long', 'x', 'y', 'policePrecinct',
#        'neighborhood', 'lastUpdateDate'],
#       dtype='object')

# %%
ax = cbr17.plot.bar(y = 'OBJECTID', figsize = (20,12))
ax.set_title('Police Stops by Race', fontsize = 24)
ax.set_ylabel('Number of Stops', fontsize = 16)
ax.tick_params(axis = "y", labelsize = 12)
ax.set_xlabel('Race', fontsize = 16)
ax.tick_params(axis = "x", labelsize = 16, labelrotation = 0.0)

# %%
ax = cbr17.plot.pie(y = 'OBJECTID', figsize = (15, 15))

# %% [markdown]
# ---

# %% [markdown]
# ### **Putting it all together**

# %% [markdown]
# We now have the total number of stops for white subjects and subjects of color.  What remains to get the total number of searches for white subjects and people of color.  We can combine indexing and grouping to do this:

# %%
# -- create a new data frame with only YES for personSearched
print("personSearch values: {0}".format(np.unique(sub17["personSearch"])))

searched17 = sub17[sub17['personSearch'] == "YES"]

display(searched17)
# Out:
# personSearch values: ['NO' 'YES']
#        OBJECTID masterIncidentNumber              responseDate  \
# 1008      10009            17-029800  2017-01-25T23:08:50.000Z
# 1016      10017            17-029861  2017-01-26T00:04:34.000Z
# 1018      10019            17-029877  2017-01-26T00:33:27.000Z
# 1020      10021            17-029892  2017-01-26T01:02:57.000Z
# 1047      10048            17-030205  2017-01-26T11:24:36.000Z
# ...         ...                  ...                       ...
# 94560     95561            17-411316  2017-10-25T07:42:46.000Z
# 94575     95576            17-437921  2017-11-15T07:29:24.000Z
# 94578     95579            17-439175  2017-11-16T06:29:54.000Z
# 94586     95587            17-452847  2017-11-28T07:53:05.000Z
# 94589     95590            17-454423  2017-11-29T08:55:31.000Z
#
#                 reason                      problem callDisposition  \
# 1008               NaN       Suspicious Vehicle (P)      TAG-Tagged
# 1016               NaN       Suspicious Vehicle (P)     BKG-Booking
# 1018               NaN  Traffic Law Enforcement (P)     ADV-Advised
# 1020               NaN  Traffic Law Enforcement (P)      RPT-Report
# 1047               NaN       Suspicious Vehicle (P)     BKG-Booking
# ...                ...                          ...             ...
# 94560  Citizen / 9-1-1        Suspicious Person (P)      RPT-Report
# 94575  Citizen / 9-1-1       Suspicious Vehicle (P)     AOK- All OK
# 94578  Citizen / 9-1-1          Attempt Pick-Up (P)     BKG-Booking
# 94586    Investigative  Traffic Law Enforcement (P)      TAG-Tagged
# 94589  Citizen / 9-1-1       Suspicious Vehicle (P)      RPT-Report
#
#       citationIssued personSearch vehicleSearch          preRace  \
# 1008             NaN          YES           YES            White
# 1016             NaN          YES           YES          Unknown
# 1018             NaN          YES           YES          Unknown
# 1020             NaN          YES           YES          Unknown
# 1047             NaN          YES           YES          Unknown
# ...              ...          ...           ...              ...
# 94560            YES          YES            NO            White
# 94575             NO          YES           YES            White
# 94578             NO          YES            NO  Native American
# 94586            YES          YES           YES          Unknown
# 94589             NO          YES           YES          Unknown
#
#                   race  gender        lat       long             x  \
# 1008             White  Female  44.926830 -93.272740 -1.038307e+07
# 1016             Black  Female  45.008540 -93.263110 -1.038200e+07
# 1018             Black    Male  44.950750 -93.281330 -1.038403e+07
# 1020   Native American    Male  45.005270 -93.266160 -1.038234e+07
# 1047             Black  Female  44.999160 -93.295640 -1.038562e+07
# ...                ...     ...        ...        ...           ...
# 94560            White    Male  44.962747 -93.241720 -1.037962e+07
# 94575            White    Male  44.972654 -93.313453 -1.038761e+07
# 94578  Native American    Male  44.963780 -93.251653 -1.038073e+07
# 94586           Latino    Male  45.014791 -93.268921 -1.038265e+07
# 94589  Native American  Female  44.956460 -93.245966 -1.038009e+07
#
#                   y  policePrecinct      neighborhood  \
# 1008   5.610009e+06             3.0            Regina
# 1016   5.622866e+06             2.0           Holland
# 1018   5.613771e+06             5.0          Whittier
# 1020   5.622351e+06             2.0         Bottineau
# 1047   5.621389e+06             4.0      Near - North
# ...             ...             ...               ...
# 94560  5.615659e+06             3.0            Seward
# 94575  5.617217e+06             4.0       Bryn - Mawr
# 94578  5.615821e+06             3.0   Ventura Village
# 94586  5.623850e+06             2.0  Marshall Terrace
# 94589  5.614670e+06             3.0     East Phillips
#
#                  lastUpdateDate
# 1008   2017-08-08T10:25:31.000Z
# 1016   2017-08-08T10:25:31.000Z
# 1018   2017-08-08T10:25:31.000Z
# 1020   2017-08-08T10:25:31.000Z
# 1047   2017-08-08T10:25:31.000Z
# ...                         ...
# 94560  2018-10-02T13:45:16.000Z
# 94575  2018-10-02T13:45:16.000Z
# 94578  2018-10-02T13:45:49.000Z
# 94586  2018-10-02T13:45:49.000Z
# 94589  2018-10-02T13:45:49.000Z
#
# [5591 rows x 19 columns]

# %%
# -- we can group and count exactly as we did with the full DataFrame to count 
#    the total number of searched persons by race.

# -- make searched counts by race DataFrame
sbr17 = searched17.groupby(['race']).count()

# -- get the total number of stopped white persons (nb, we know that OBJECTID 
#    has no NaN values)
nsearch_wht = sbr17["OBJECTID"].loc["White"]

# -- get the total non-white stops (NOTE: IT'S IMPORTANT THAT WE HAVE EXCLUDED 
#    THE "UNKNOWN" CATEGORY)
nsearch_poc = sbr17["OBJECTID"].loc[rind[:6]].sum()

# %% [markdown]
# **And so finally, we can divide to get the ratio:**

# %%
print("fraction of stopped white persons that are searched    : {0:4.3}".format(nsearch_wht / nstop_wht))
print("fraction of stopped persons of color that are searched : {0:4.3}".format(nsearch_poc / nstop_poc))
# Out:
# fraction of stopped white persons that are searched    : 0.0854
# fraction of stopped persons of color that are searched : 0.189

# %% [markdown]
# How do we interpret these results?  What caveats are there?

# %% [markdown]
# FWIW, we can also divide one DataFrame by another (element-wise):

# %%
sbr17 / cbr17
# Out:
#                  OBJECTID  masterIncidentNumber  responseDate    reason  \
# race
# Asian            0.101040              0.101040      0.101040  0.104628
# Black            0.208360              0.208360      0.208360  0.215130
# East African     0.078202              0.078202      0.078202  0.087087
# Latino           0.121006              0.121006      0.121006  0.125086
# Native American  0.313591              0.313591      0.313591  0.309881
# Other            0.135021              0.135021      0.135021  0.143403
# Unknown          0.010886              0.010886      0.010886  0.011419
# White            0.085425              0.085425      0.085425  0.087887
#
#                   problem  callDisposition  citationIssued  personSearch  \
# race
# Asian            0.101040         0.101040        0.088462      0.101040
# Black            0.208360         0.208360        0.222973      0.208360
# East African     0.078202         0.078202        0.100473      0.078202
# Latino           0.121006         0.121006        0.128342      0.121006
# Native American  0.313591         0.313591        0.303935      0.313591
# Other            0.135021         0.135021        0.151920      0.135021
# Unknown          0.010886         0.010886        0.011934      0.010886
# White            0.085425         0.085425        0.088308      0.085425
#
#                  vehicleSearch   preRace    gender       lat      long  \
# race
# Asian                 0.101040  0.101040  0.101040  0.101040  0.101040
# Black                 0.208360  0.208360  0.208360  0.208360  0.208360
# East African          0.078202  0.078202  0.078202  0.078202  0.078202
# Latino                0.121006  0.121006  0.121006  0.121006  0.121006
# Native American       0.313591  0.313591  0.313591  0.313591  0.313591
# Other                 0.135021  0.135021  0.135021  0.135021  0.135021
# Unknown               0.010886  0.010886  0.010886  0.010886  0.010886
# White                 0.085425  0.085425  0.085425  0.085425  0.085425
#
#                         x         y  policePrecinct  neighborhood  \
# race
# Asian            0.101040  0.101040        0.103030      0.103030
# Black            0.208360  0.208360        0.209607      0.209607
# East African     0.078202  0.078202        0.078912      0.078912
# Latino           0.121006  0.121006        0.122158      0.122158
# Native American  0.313591  0.313591        0.315224      0.315224
# Other            0.135021  0.135021        0.136006      0.136006
# Unknown          0.010886  0.010886        0.010986      0.010986
# White            0.085425  0.085425        0.086128      0.086128
#
#                  lastUpdateDate
# race
# Asian                  0.101040
# Black                  0.208360
# East African           0.078202
# Latino                 0.121006
# Native American        0.313591
# Other                  0.135021
# Unknown                0.010886
# White                  0.085425

# %%
df = pd.DataFrame({'race': ['White', 'Black'], 'stop': [(nsearch_wht / nstop_wht) * 100, (nsearch_poc / nstop_poc) * 100]})

# %%
ax = df.plot.bar(x = 'race', y = 'stop', figsize = (20,12))
ax.set_title('Police Stoped and Searched by Race', fontsize = 24)
ax.set_ylabel('Percentage (%)', fontsize = 16)
ax.tick_params(axis = "y", labelsize = 12)
ax.set_xlabel('Race', fontsize = 16)
ax.tick_params(axis = "x", labelsize = 16, labelrotation = 0.0)
